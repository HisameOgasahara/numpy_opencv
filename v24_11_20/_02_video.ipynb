# %%
#무조건 외워야 할 기본 코드 (넘파이는 내 편의상 넣은거)

import cv2
import numpy as np

img_src = cv2.imread(r"C:\Users\HKIT\vscode\numpy\v24_11_20\img\shogun.webp", cv2.IMREAD_COLOR) #이미지를 img_src에 로딩해 왔다는 의미
if img_src is None:
    print("이미지 로딩 불가")
    exit(1)
else:
    height, width = img_src[:2] 
    cv2.imshow('src', img_src)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
#이미지 저장 코드

img_src = cv2.imread(r"C:\Users\HKIT\vscode\numpy\v24_11_20\img\lycoreco2.jpg", cv2.IMREAD_COLOR) #이미지를 img_src에 로딩해 왔다는 의미
cv2.imwrite(r'img\saved_image.png', img_src) #png, webp등 다른 확장자도 가능
# Out:
# True

# %%
#동영상 끝가지 재생되면 종료

import cv2

capture = cv2.VideoCapture(r'video\bocchi_live.mp4') #통째로 동영상을 
if capture.isOpened() == False:
    print("동영상을 열 수 없어")
    exit(1)

while (1): #동영상은 끝날 때까지 재생되어야 하니
    ret, frame = capture.read() #동영상을 한 프레임씩. frame은 img_src라 보면 된다 
    if ret == False: #동영상 읽기 완료
        print("동영상 끝")
        break
    cv2.imshow("video", frame) #거듭 말하지만 frame은 img_src라 보면 된다 
    if cv2.waitKey(33)==27: 
        break
capture.release()
cv2.destroyAllWindows()

# %%
# 무한반복

import cv2

capture = cv2.VideoCapture(r'video\bocchi_live.mp4')
if capture.isOpened() == False:
    print("동영상을 열 수 없어")
    exit(1)

while (1): 
    ret, frame = capture.read() 
    if capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT): #무한재생
        capture.set(cv2.CAP_PROP_POS_FRAMES, 0)

    cv2.imshow("video", frame) 
    if cv2.waitKey(33)==27: #27은 아스키코드. ESC키를 누르면 종료되게
        break
capture.release()
cv2.destroyAllWindows()

# %%
#이미지 grayscale로 변환하기

import cv2
img_src =cv2.imread(r'img\bocchi4.jpg')
height, width = img_src[:2]


# 원본은 img_src
# 이미지를 gray로 변경

img_gray = cv2.cvtColor(img_src, cv2.COLOR_BGR2GRAY)
cv2.imshow('src', img_src)
cv2.imshow('gray', img_gray)


cv2.imshow('src', img_src)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#동영상 끝가지 재생되면 종료

import cv2

capture = cv2.VideoCapture(r'video\bocchi_live.mp4') #통째로 동영상을 
if capture.isOpened() == False:
    print("동영상을 열 수 없어")
    exit(1)

while (1): #동영상은 끝날 때까지 재생되어야 하니
    ret, frame = capture.read() #동영상을 한 프레임씩. frame은 img_src라 보면 된다 
    if ret == False: #동영상 읽기 완료
        print("동영상 끝")
        break

    #############이 안에 동영상에 원하는 기능 구현######################
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) #3채널을 1채널로
    frame_gray = cv2.cvtColor(frame_gray, cv2.COLOR_GRAY2BGR) #1채널을 3채널로 채널 맞추기
    frame_dst = cv2.hconcat([frame,frame_gray])
    #####################################################################

    cv2.imshow("video", frame_dst)
    if cv2.waitKey(33)==27: 
        break
capture.release()
cv2.destroyAllWindows()

# %%
# 동영상이 끝까지 재생되면 다시 처음으로
import cv2

capture = cv2.VideoCapture(r'video\bocchi_live.mp4')
if capture.isOpened() == False:
    print('동영상을 열수 없습니다.')
    exit(1)
frame_num = capture.get(cv2.CAP_PROP_FRAME_COUNT)
while True:
    ret, frame = capture.read()  # frame이 img_src랑 동일하게 생각!!!
    if capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT):
        capture.set(cv2.CAP_PROP_POS_FRAMES, 0)
    frame_now = capture.get(cv2.CAP_PROP_POS_FRAMES)
    frame = cv2.putText(frame,f'{int(frame_now):04d} / {int(frame_num):04d}', (10,30), 
                        cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2)
    
    ###################### 동영상에 원하는 기능을 구현 ##############################
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)      # 3CH -> 1CH
    print(frame_gray.shape)
    frame_gray = cv2.cvtColor(frame_gray, cv2.COLOR_GRAY2BGR) # 1CH -> 3CH

    frame_dst = cv2.hconcat([frame,frame_gray])   # 동영상 가로로 합치기
    # frame_dst = cv2.vconcat([frame,frame_gray])   # 동영상 세로로 합치기
    ###############################################################################
    cv2.imshow('video',frame_dst)
    if cv2.waitKey(33) == 27: # Esc
        break
capture.release()
cv2.destroyAllWindows()
# Out:
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)
# (1080, 1920)

# %%
import cv2
img_src = cv2.imread(r'img\bocchi4.jpg')
height, width = img_src[:2]

# 원본 영상 : img_src
################# 이미지 대칭 적용하기 ####################
img_src = cv2.pyrDown(img_src)

img_flip_lr = cv2.flip(img_src, 1)   # 좌우
img_flip_ud = cv2.flip(img_src, 0)   # 상하
img_flip_lrud = cv2.flip(img_src, -1)   # 상하좌우

img_dst1 = cv2.hconcat([img_src, img_flip_lr])
img_dst2 = cv2.hconcat([img_flip_ud, img_flip_lrud])
img_dst = cv2.vconcat([img_dst1, img_dst2])

##########################################################
cv2.imshow('src',img_dst)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
# 동영상이 끝까지 재생되면 다시 처음으로
import cv2

capture = cv2.VideoCapture(r'video\frieren.mp4')
if capture.isOpened() == False:
    print('동영상을 열수 없습니다.')
    exit(1)
frame_num = capture.get(cv2.CAP_PROP_FRAME_COUNT)
while True:
    ret, frame = capture.read()  # frame이 img_src랑 동일하게 생각!!!
    if capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT):
        capture.set(cv2.CAP_PROP_POS_FRAMES, 0)
    frame_now = capture.get(cv2.CAP_PROP_POS_FRAMES)
    frame = cv2.putText(frame,f'{int(frame_now):04d} / {int(frame_num):04d}', (10,30), 
                        cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2)
    
    ###################### 동영상에 원하는 기능을 구현 ##############################
    frame_src = cv2.pyrDown(frame)

    frame_flip_lr = cv2.flip(frame_src, 1)   # 좌우
    frame_flip_ud = cv2.flip(frame_src, 0)   # 상하
    frame_flip_lrud = cv2.flip(frame_src, -1)   # 상하좌우

    frame_dst1 = cv2.hconcat([frame_src, frame_flip_lr])
    frame_dst2 = cv2.hconcat([frame_flip_ud, frame_flip_lrud])
    frame_dst = cv2.vconcat([frame_dst1, frame_dst2])
    ###############################################################################
    cv2.imshow('video',frame_dst)
    if cv2.waitKey(33) == 27: # Esc
        break
capture.release()
cv2.destroyAllWindows()

# %%
#이미지 회전

# 회전행렬 : matrix = cv2.getRotationMatrix2D((중심점w, 중심점h), 회전각도, 스케일=1)
# 행렬적용 : img_dst = cv2.warpAffine(img_src, matrix, (이미지 크기w, 이미지 크기h))

import cv2
img_src = cv2.imread(r'img\bocchi4.jpg')
height, width = img_src.shape[:2] #shape를 해야함에 유의

# 원본 영상 : img_src
################# 이미지 회전 적용 ####################
matrix = cv2.getRotationMatrix2D((width//2, height//2), 90, 1)
img_dst1 = cv2.warpAffine(img_src, matrix, (width,height))
##########################################################
cv2.imshow('src',img_dst)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
# 동영상이 끝까지 재생되면 다시 처음으로
import cv2

capture = cv2.VideoCapture(r'video\frieren.mp4')
if capture.isOpened() == False:
    print('동영상을 열수 없습니다.')
    exit(1)
frame_num = capture.get(cv2.CAP_PROP_FRAME_COUNT)
while True:
    ret, frame = capture.read()  
    height, width = frame.shape[:2] # 높이와 너비를 얻는 부분 추가
    if capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT):
        capture.set(cv2.CAP_PROP_POS_FRAMES, 0)
    frame_now = capture.get(cv2.CAP_PROP_POS_FRAMES)
    frame = cv2.putText(frame,f'{int(frame_now):04d} / {int(frame_num):04d}', (10,30), 
                        cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2)
    
    ###################### 동영상에 원하는 기능을 구현 ##############################
    frame_src = cv2.pyrDown(frame)

    matrix = cv2.getRotationMatrix2D((frame_src.shape[1]//2, frame_src.shape[0]//2), 180, 1) # frame_src의 크기 사용
    frame_rot180 = cv2.warpAffine(frame_src, matrix, (frame_src.shape[1], frame_src.shape[0])) # frame_src의 크기 사용

    frame_dst = cv2.hconcat([frame_src, frame_rot180])
    ###############################################################################
    cv2.imshow('video',frame_dst)
    if cv2.waitKey(33) == 27: # Esc
        break
capture.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 이미지 크기 조절
# - 이미지 2배 축소 (1/2) : img_dst = cv2.pyrDown(img_src)
# - 이미지 2배 확대 (x2) : img_dst = cv2.pyrUp(img_src, dstsize=(width*2, height*2), borderType=cv2.BORDER_DEFAULT)
# - 이미지 크기조절 : resize
# - 원하는 크기로 크기조절 : img_dst = cv2.resize(img_src, dsize=(이미지w, 이미지h), interpolation=cv2.INTER_LINEAR)
# - 원하는 배율로 크기조절 : img_dst = cv2.resize(img_src, dsize=(0, 0), fx=배율, fy=배율, interpolation=cv2.INTER_AREA)

# %%
import cv2
img_src = cv2.imread(r'img\bocchi4.jpg')
height,width = img_src.shape[:2]
################# 이미지 크기 절반으로 줄이기 #############
img_dst = cv2.pyrDown(img_src)
#########################################################
cv2.imshow('src',img_src)
cv2.imshow('dst',img_dst)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
img_src = cv2.imread(r'img\bocchi4.jpg', cv2.IMREAD_COLOR)
height,width = img_src.shape[:2]
#################### 이미지 resize  #####################
img_dst = cv2.resize(img_src, dstsize=(width*0.7,height*0.7),interpolation=cv2.INTER_CUBIC)
#########################################################
cv2.imshow('src',img_src)
cv2.imshow('dst',img_dst)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 5
#       3 height,width = img_src.shape[:2]
#       4 #################### 이미지 resize  #####################
# ----> 5 img_dst = cv2.resize(img_src, dstsize=(width*0.7,height*0.7),interpolation=cv2.INTER_CUBIC)
#       6 #########################################################
#       7 cv2.imshow('src',img_src)
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - resize() missing required argument 'dsize' (pos 2)
# >  - resize() missing required argument 'dsize' (pos 2)

# %%
import cv2

img_src = cv2.imread(r'img\bocchi4.jpg', cv2.IMREAD_COLOR)
# 이미지 파일이 존재하는지 확인하는 부분 추가
if img_src is None:
    print("이미지 파일을 찾을 수 없습니다. 파일 경로를 확인하세요.")
    exit()

height,width = img_src.shape[:2]
#################### 이미지 resize  #####################
img_resize1 = cv2.resize(img_src, dsize=(0,0),fx=0.5, fy=0.5, interpolation=cv2.INTER_CUBIC)
img_resize2a = cv2.resize(img_src, dsize=(0,0),fx=0.5, fy=0.5, interpolation=cv2.INTER_CUBIC)
img_resize2b = cv2.flip(img_resize2a, 0)
img_resize12 = cv2.vconcat([img_resize1, img_resize2b])
img_dst = cv2.hconcat([img_src, img_resize12])
#########################################################
cv2.imshow('src',img_dst)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# 동영상이 끝까지 재생되면 다시 처음으로
import cv2

capture = cv2.VideoCapture(r'video\frieren.mp4')
if capture.isOpened() == False:
    print('동영상을 열수 없습니다.')
    exit(1)
frame_num = capture.get(cv2.CAP_PROP_FRAME_COUNT)
while True:
    ret, frame = capture.read()  
    height, width = frame.shape[:2] # 높이와 너비를 얻는 부분 추가
    if capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT):
        capture.set(cv2.CAP_PROP_POS_FRAMES, 0)
    frame_now = capture.get(cv2.CAP_PROP_POS_FRAMES)
    frame = cv2.putText(frame,f'{int(frame_now):04d} / {int(frame_num):04d}', (10,30), 
                        cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2)
    
    ###################### 동영상에 원하는 기능을 구현 ##############################
    frame_src = cv2.pyrDown(frame)

    frame_resize1 = cv2.resize(frame_src, dsize=(0,0),fx=0.5, fy=0.5, interpolation=cv2.INTER_CUBIC)
    frame_resize1_gray = cv2.cvtColor(frame_resize1, cv2.COLOR_BGR2GRAY)
    frame_resize1_gray = cv2.cvtColor(frame_resize1_gray, cv2.COLOR_GRAY2BGR) #흑백칼라 채널 전환시 차원조절. 위에
    frame_resize2a = cv2.resize(frame_src, dsize=(0,0),fx=0.5, fy=0.5, interpolation=cv2.INTER_CUBIC)
    frame_resize2b = cv2.flip(frame_resize2a, 0)
    frame_resize2b_gray = cv2.cvtColor(frame_resize2b, cv2.COLOR_BGR2GRAY)
    frame_resize2b_gray = cv2.cvtColor(frame_resize2b_gray, cv2.COLOR_GRAY2BGR)
    frame_resize12 = cv2.vconcat([frame_resize1_gray, frame_resize2b_gray])
    frame_dst = cv2.hconcat([frame_src, frame_resize12])
    ###############################################################################
    cv2.imshow('video',frame_dst)
    if cv2.waitKey(33) == 27: # Esc
        break
capture.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 이미지 자르기
#
# - 원하는영역 자르기 : img_roi = img_src[h_start:h_end, w_start:w_end]

# %%
import cv2
img_src = cv2.imread('img/pawn.png',cv2.IMREAD_COLOR)
height,width = img_src.shape[:2]
#################### 이미지 자르기  ######################
#img_roi = img_src[h_start:h_end,w_start:w_end] (h==y, w==x)
img_roi = img_src[265:865,50:320]
img_roi = cv2.cvtColor(img_roi,cv2.COLOR_BGR2GRAY)
img_roi = cv2.cvtColor(img_roi,cv2.COLOR_GRAY2BGR)

img_roi2 = img_src[365:825,470:660]
img_roi2 = cv2.cvtColor(img_roi2,cv2.COLOR_BGR2GRAY)
img_roi2 = cv2.cvtColor(img_roi2,cv2.COLOR_GRAY2BGR)

img_roi3 = img_src[470:825,815:1020]
img_roi3 = cv2.cvtColor(img_roi3,cv2.COLOR_BGR2GRAY)
img_roi3 = cv2.cvtColor(img_roi3,cv2.COLOR_GRAY2BGR)

img_src[265:865,50:320] = img_roi
img_src[365:825,470:660] = img_roi2
img_src[470:825,815:1020] = img_roi3
#########################################################
cv2.imshow('src',img_src)
cv2.imshow('roi',img_roi)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# 동영상이 끝까지 재생되면 다시 처음으로
import cv2

capture = cv2.VideoCapture(r'video\frieren.mp4')
if capture.isOpened() == False:
    print('동영상을 열수 없습니다.')
    exit(1)
frame_num = capture.get(cv2.CAP_PROP_FRAME_COUNT)
while True:
    ret, frame = capture.read()  
    height, width = frame.shape[:2] # 높이와 너비를 얻는 부분 추가
    if capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT):
        capture.set(cv2.CAP_PROP_POS_FRAMES, 0)
    frame_now = capture.get(cv2.CAP_PROP_POS_FRAMES)
    frame = cv2.putText(frame,f'{int(frame_now):04d} / {int(frame_num):04d}', (10,30), 
                        cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2)
    
    ###################### 동영상에 원하는 기능을 구현 ##############################
    frame_roi = frame[height*1/4:height*3/4,width*1/4:width*3/4]
    frame_roi = cv2.cvtColor(frame_roi,cv2.COLOR_BGR2GRAY)
    frame_roi = cv2.cvtColor(frame_roi,cv2.COLOR_GRAY2BGR)
    frame[height*1/4:height*3/4,width*1/4:width*3/4] = frame_roi
    ###############################################################################
    cv2.imshow('video',frame_roi)
    if cv2.waitKey(33) == 27: # Esc
        break
capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 19
#      15 frame = cv2.putText(frame,f'{int(frame_now):04d} / {int(frame_num):04d}', (10,30),
#      16                     cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2)
#      18 ###################### 동영상에 원하는 기능을 구현 ##############################
# ---> 19 frame_roi = frame[height*1/4:height*3/4,width*1/4:width*3/4]
#      20 frame_roi = cv2.cvtColor(frame_roi,cv2.COLOR_BGR2GRAY)
#      21 frame_roi = cv2.cvtColor(frame_roi,cv2.COLOR_GRAY2BGR)
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
import cv2

capture = cv2.VideoCapture(r'video\frieren.mp4')
if capture.isOpened() == False:
    print('동영상을 열수 없습니다.')
    exit(1)
frame_num = capture.get(cv2.CAP_PROP_FRAME_COUNT)
while True:
    ret, frame = capture.read()  
    if not ret:  # 비디오 파일의 끝에 도달했는지 확인. ret 값이 False가 되면 종료
        break
    height, width = frame.shape[:2] # 높이와 너비를 얻는 부분 추가
    if capture.get(cv2.CAP_PROP_POS_FRAMES) == capture.get(cv2.CAP_PROP_FRAME_COUNT):
        capture.set(cv2.CAP_PROP_POS_FRAMES, 0)
    frame_now = capture.get(cv2.CAP_PROP_POS_FRAMES)
    frame = cv2.putText(frame,f'{int(frame_now):04d} / {int(frame_num):04d}', (10,30), 
                        cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2)
    
    ###################### 동영상에 원하는 기능을 구현 ##############################
    frame_roi = frame[height//4:height*3//4, width//4:width*3//4] # // 연산자 사용하여 정수 나눗셈
    frame_roi = cv2.cvtColor(frame_roi,cv2.COLOR_BGR2GRAY)
    frame_roi = cv2.cvtColor(frame_roi,cv2.COLOR_GRAY2BGR)
    frame[height//4:height*3//4, width//4:width*3//4] = frame_roi
    ###############################################################################
    cv2.imshow('video', frame) # frame_dst 대신 frame 사용
    if cv2.waitKey(33) == 27: # Esc
        break
capture.release()
cv2.destroyAllWindows()
